# %%
from your_job_offer.services.mail_checker.methods import get_email_messages
from your_job_offer.use_cases.tracking.internal import *
from your_job_offer.utils.mock import get_user
    
def print_with_line_breaks(text, line_length=100):
    """Выводит длинную строку с переносами на заданную длину.
    
    :param text: Исходный текст для вывода.
    :param line_length: Максимальная длина строки.
    """
    while len(text) > line_length:
        # Найдем место для разбиения строки, чтобы не разрывать слова
        break_index = text.rfind(' ', 0, line_length)
        if break_index == -1:  # Нет пробела, берем отрезок от начала
            break_index = line_length
        
        print(text[:break_index])  # Выводим часть строки
        text = text[break_index:].lstrip()  # Убираем пробелы и продолжаем

    # Выводим оставшуюся часть текста
    print(text)
    print()

def print_messages(messages):
    for message in messages:
        print_with_line_breaks(message.body)

user = get_user()
messages = get_email_messages(user)
print_messages(messages)
filtered = filter_from_spam(messages)
cleaned = clean_messages(filtered)
# Out:
# <!doctype html>
# <html lang="ru" xmlns="http://www.w3.org/1999/xhtml"
# xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
#
# <head>
#     <title>
#       Yandex ID
#     </title>
#     <!--[if !mso]><!-->
#     <meta
# http-equiv="X-UA-Compatible" content="IE=edge">
#     <!--<![endif]-->
#     <meta
# http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta name="viewport"
# content="width=device-width, initial-scale=1">
#     <style type="text/css">
#       #outlook a {
# padding:0; }
#       body {
# margin:0;padding:0;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%; }
#       table, td {
# border-collapse:collapse;mso-table-lspace:0pt;mso-table-rspace:0pt; }
#       img {
# border:0;height:auto;line-height:100%;
# outline:none;text-decoration:none;-ms-interpolation-mode:bicubic; }
#       p {
# display:block;margin:13px 0; }
#     </style>
#     <!--[if mso]>
#     <noscript>
#     <xml>
#
# <o:OfficeDocumentSettings>
#       <o:AllowPNG/>
#       <o:PixelsPerInch>96</o:PixelsPerInch>
#
# </o:OfficeDocumentSettings>
#     </xml>
#     </noscript>
#     <![endif]-->
#     <!--[if lte mso 11]>
#
# <style type="text/css">
#       .mj-outlook-group-fix { width:100% !important; }
#     </style>
#
# <![endif]-->
#
#       <!--[if !mso]><!-->
#         <link
# href="https://yastatic.net/s3/frontend/yandex-font/v0.2.0/browser.css" rel="stylesheet"
# type="text/css">
#         <style type="text/css">
#           @import
# url(https://yastatic.net/s3/frontend/yandex-font/v0.2.0/browser.css);
#         </style>
#
# <!--<![endif]-->
#
#
#
#     <style type="text/css">
#       @media only screen and (min-width:540px) {
#
# .mj-column-per-100 { width:100% !important; max-width: 100%; }
#       }
#     </style>
#     <style
# media="screen and (min-width:540px)">
#       .moz-text-html .mj-column-per-100 { width:100%
# !important; max-width: 100%; }
#     </style>
#
#
#     <style type="text/css">
#
#
#         .card a {
#
# color: #4D8EFF;
#         }
#         .card a:hover {
#             color: #FF4D4D;
#         }
#
# @media (prefers-color-scheme: dark ) {
#             .card a {
#               color: #6BA6F6
# !important;
#             }
#           }
#         [data-ogsc] .card a { color: #6BA6F6 !important; }
#
#
# @media only screen and (max-width:540px) {
#       table.mj-full-width-mobile { width: 100%
# !important; }
#       td.mj-full-width-mobile { width: auto !important; }
#     }
#
#           a {
#
# text-decoration: none;
#             font-weight: 500;
#           }
#           a:hover {
#
# color: #262633;
#           }
#           .text_size_s {
#             font-size: 16px;
#
# line-height: 22px;
#           }
#           .text_color_secondary {
#             color: #85889E;
#
# }
#           .text ul, .text ol {
#             margin: 0 0 0 28px;
#             padding: 0;
#
# }
#           .text li {
#             margin: 0 0 8px;
#             padding-left: 6px;
#           }
#
# p {
#             margin: 0 0 12px;
#           }
#
#     </style>
#     <style type="text/css">
#
#
# </style>
#
#   </head>
#   <body style="word-spacing:normal;background-color:#E5E5E5;">
#
#
#       <div
# style="background-color:#E5E5E5;">
#
#       <div
# style="height:24px;line-height:24px;">&#8202;</div>
#
#             <div style="margin: 0 8px">
#
#
#
# <!--[if mso | IE]><table align="center" border="0" cellpadding="0" cellspacing="0"
# class="card-outlook" role="presentation" style="width:520px;" width="520" bgcolor="#C5ECB8"
# ><tr><td style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><v:rect
# style="width:520px;" xmlns:v="urn:schemas-microsoft-com:vml" fill="true" stroke="false"><v:fill
# origin="0.5, 0" position="0.5, 0" src="https://id-mail.s3.yandex.net/security/security.png"
# color="#C5ECB8" type="tile" /><v:textbox style="mso-fit-shape-to-text:true"
# inset="0,0,0,0"><![endif]-->
#
#       <div class="card" style="background:#C5ECB8
# url('https://id-mail.s3.yandex.net/security/security.png') right top / auto
# no-repeat;background-position:right top;background-repeat:no-repeat;background-size:auto;margin:0px
# auto;border-radius:32px;max-width:520px;">
#         <div style="line-height:0;font-size:0;">
#
# <table align="center" background="https://id-mail.s3.yandex.net/security/security.png" border="0"
# cellpadding="0" cellspacing="0" role="presentation" style="background:#C5ECB8
# url('https://id-mail.s3.yandex.net/security/security.png') right top / auto
# no-repeat;background-position:right
# top;background-repeat:no-repeat;background-size:auto;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <table border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="border-collapse:collapse;border-spacing:0px;">
#
# <tbody>
#           <tr>
#             <td style="width:157px;">
#
#         <a
# href="https://passport.yandex.ru/profile" target="_blank" style="text-decoration: none;
# font-weight: 500;">
#
#       <img alt="Яндекс ID" height="auto"
# src="https://id-mail.s3.yandex.net/security/logo@2x.png"
# style="border:0;display:block;outline:none;text-decoration:none;height:auto;width:100%;font-size:13p
# x;" width="157">
#
#         </a>
#
#             </td>
#           </tr>
#         </tbody>
#       </table>
#
#
# </td>
#               </tr>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div
# style="height:50px;line-height:50px;">&#8202;</div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h1 style="font-size: 28px;
# line-height: 32px; margin: 0 0 16px 0; font-weight: 700">
#                     Вы создали пароль для
# приложения в аккаунте YourJobOffer2
#                 </h1></div>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td align="left" class="text"
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">21.11.2024 12:39<br>
#
# IP 89.113.147.183 • Москва</div>
#
#                 </td>
#               </tr>
#
#         </tbody>
#
# </table>
#
#       </div>
#
#           <!--[if mso | IE]></td></tr></table><![endif]-->
#
# </td>
#             </tr>
#           </tbody>
#         </table>
#         </div>
#       </div>
#
#
# <!--[if mso | IE]></v:textbox></v:rect></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#             <div
# style="margin: 0 8px">
#
#
#       <!--[if mso | IE]><table align="center" border="0" cellpadding="0"
# cellspacing="0" class="card-outlook" role="presentation" style="width:520px;" width="520"
# bgcolor="#ffffff" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# class="card" style="background:#ffffff;background-color:#ffffff;margin:0px
# auto;border-radius:32px;max-width:520px;">
#
#         <table align="center" border="0"
# cellpadding="0" cellspacing="0" role="presentation"
# style="background:#ffffff;background-color:#ffffff;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h2 style="font-size: 24px;
# line-height: 28px; margin: 0 0 16px 0; font-weight: 700">
#           Если это были не вы
#
# </h2></div>
#
#                 </td>
#               </tr>
#
#               <tr>
#                 <td
# align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;"><p style="margin: 0 0
# 12px;">
#           Первым делом, проверьте, что данные в аккаунте — точно ваши:
#       </p>
#
# <ul style="margin: 0 0 0 28px; padding: 0;">
#             <li style="margin: 0 0 8px; padding-left:
# 6px;"><a href="https://passport.yandex.ru/profile/phones?origin=passport_profile"
# style="text-decoration: none; font-weight: 500;">Номер телефона</a></li>
#             <li
# style="margin: 0 0 8px; padding-left: 6px;"><a
# href="https://passport.yandex.ru/profile/change-hint" style="text-decoration: none; font-weight:
# 500;">Контрольный вопрос</a></li>
#             <li style="margin: 0 0 8px; padding-left: 6px;"><a
# href="https://passport.yandex.ru/profile" style="text-decoration: none; font-weight:
# 500;">Дополнительные почты</a></li>
#           </ul>
#           <p style="margin: 0 0 12px;">
#
# После этого обязательно <a href="https://passport.yandex.ru/profile/password"
# style="text-decoration: none; font-weight: 500;">смените пароль</a> — так вы не оставите лазеек
# злоумышленникам.
#
#           </p></div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="center" vertical-align="middle" style="font-size:0px;padding:32px
# 0;padding-top:20px;word-break:break-word;">
#
#       <table border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="border-collapse:separate;line-height:100%;">
#
# <tbody>
#           <tr>
#             <td align="center" bgcolor="#FDDE55" role="presentation"
# style="border:none;border-radius:16px;cursor:auto;mso-padding-alt:18px 66px;background:#FDDE55;"
# valign="middle">
#               <a href="https://passport.yandex.ru/profile/password"
# style="display: inline-block; background: #FDDE55; color: #361600; font-family: YS Text, Arial,
# sans-serif; font-size: 16px; font-weight: normal; line-height: 120%; margin: 0; text-decoration:
# none; text-transform: none; padding: 18px 66px; mso-padding-alt: 0px; border-radius: 16px;"
# target="_blank">
#                   Сменить пароль
#               </a>
#             </td>
#
# </tr>
#         </tbody>
#       </table>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#
# <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">
#
#
# Если не получается войти в аккаунт, попробуйте <a
# href="https://passport.yandex.ru/passport?mode=restore&uid=2051232599" style="text-decoration:
# none; font-weight: 500;">восстановить доступ</a> или <a
# href="https://yandex.ru/support/id/feedback.html" style="text-decoration: none; font-weight:
# 500;">напишите в службу поддержки</a>.
#
#       </div>
#
#                 </td>
#
# </tr>
#
#         </tbody>
#       </table>
#
#       </div>
#
#           <!--[if mso |
# IE]></td></tr></table><![endif]-->
#               </td>
#             </tr>
#           </tbody>
#
# </table>
#
#       </div>
#
#
#       <!--[if mso | IE]></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#             <div
# style="margin: 0 8px">
#
#
#       <!--[if mso | IE]><table align="center" border="0" cellpadding="0"
# cellspacing="0" class="card-outlook" role="presentation" style="width:520px;" width="520"
# bgcolor="#ffffff" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# class="card" style="background:#ffffff;background-color:#ffffff;margin:0px
# auto;border-radius:32px;max-width:520px;">
#
#         <table align="center" border="0"
# cellpadding="0" cellspacing="0" role="presentation"
# style="background:#ffffff;background-color:#ffffff;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h2 style="font-size: 24px;
# line-height: 28px; margin: 0 0 16px 0; font-weight: 700">
#                     Как защитить аккаунт
# от злоумышленников
#                 </h2></div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#
# <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">
#           <p
# style="margin: 0 0 12px;">
#
#               Загляните на наш обучающий лендинг: <a
# href="https://id.yandex.ru/howtoprotectyourid" style="text-decoration: none; font-weight:
# 500;">«Как сделать защиту аккаунта на Яндексе ещё сильнее»</a>.
#
#           </p>
#
# <p style="margin: 0 0 12px;">Вот несколько советов:</p></div>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#
# <table style="margin-bottom: 24px;">
#                 <tr>
#                     <td style="width:
# 44px; vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/phone.png);
#                         background-position:
# 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Привяжите номер
# телефона
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px;
# font-size: 16px; line-height: 22px; color: #85889E;">Это поможет быстро восстанавливать
# доступ</p></div>
#     </td>
#                 </tr>
#             </table>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#
# <table style="margin-bottom: 24px;">
#                 <tr>
#                     <td style="width:
# 44px; vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/key.png);
#                         background-position:
# 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Придумайте сложный
# пароль
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px;
# font-size: 16px; line-height: 22px; color: #85889E;">Обязательно с буквами и цифрами</p></div>
#
# </td>
#                 </tr>
#             </table>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#             <table
# style="margin-bottom: 0px;">
#                 <tr>
#                     <td style="width: 44px;
# vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/shield.png);
#
# background-position: 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Включите подтверждение
# входа
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px; font-size:
# 16px; line-height: 22px; color: #85889E;">Входите с паролем и смс или с приложением Яндекс
# Ключ</p></div>
#     </td>
#                 </tr>
#             </table>
#
#                 </td>
#
# </tr>
#
#         </tbody>
#       </table>
#
#       </div>
#
#           <!--[if mso |
# IE]></td></tr></table><![endif]-->
#               </td>
#             </tr>
#           </tbody>
#
# </table>
#
#       </div>
#
#
#       <!--[if mso | IE]></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#
#       <!--[if mso |
# IE]><table align="center" border="0" cellpadding="0" cellspacing="0" class="" role="presentation"
# style="width:520px;" width="520" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# style="margin:0px auto;max-width:520px;">
#
#         <table align="center" border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="width:100%;">
#           <tbody>
#             <tr>
#
# <td style="direction:ltr;font-size:0px;padding:20px 0;text-align:center;">
#                 <!--[if
# mso | IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:520px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# align="center" class="text" style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:16px;line-height:22px;text-align:center;color:#85889E;">На это письмо не нужно
# отвечать.<br>
#       <a href="https://id.yandex.ru/helpdesk/e0271d00-30f7-9cf7-4c16-c3f95d5b10cd"
# style="text-decoration: none; font-weight: 500; color: #85889E;">Связаться с поддержкой Яндекс
# ID</a></div>
#
#                 </td>
#               </tr>
#
#         </tbody>
#       </table>
#
#
# </div>
#
#           <!--[if mso | IE]></td></tr></table><![endif]-->
#               </td>
#
# </tr>
#           </tbody>
#         </table>
#
#       </div>
#
#
#       <!--[if mso |
# IE]></td></tr></table><![endif]-->
#
#
#       </div>
#
#   </body>
# </html>
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 18:20
# Subject: Сообщение от работодателя
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested&sent_date=2024_11_14&utm_content=logo&email_hash=1d350faab33bb7b3a16473c547015887>
# «Здравствуйте, Руслан Ильдарович,
#
# Компания Группа компаний Астра рассмотрит Ваше резюме на
# вакансию Стажер
# мантейнер и позже сообщит Вам о своем решении.
#
# С уважением,
# Максимова
# Александра»
#
#
# Вакансия: Стажер мантейнер
#
# компании: Группа компаний Астра
#
# Посмотреть
# вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/109143498?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested&utm_content=text&sent_date=2024_11_14&email_hash=1d350faab33bb7b3a16473c547015887>
#
#
#
# *Те
# перь вы можете отписаться от этого типа письма. *
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested&se
# nt_date=2024_11_14&utm_content=feedback&email_hash=1d350faab33bb7b3a16473c547015887>
# Управление
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested&sent_date=2024_11_14&utm_content=unsubscr
# ibe&email_hash=1d350faab33bb7b3a16473c547015887>
# <https://vk.com/headhunter>
# <https://t.me/hh_ru_o
# fficial>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
#
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес
# 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний HeadHunter,
# 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 18:20
# Subject: Сообщение от работодателя
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested&sent_date=2024_11_14&utm_content=logo&email_hash=8d943b26b592ba0cb731fb7b6bf5e054>
# «Здравствуйте, Руслан Ильдарович,
#
# Компания Группа компаний Астра рассмотрит Ваше резюме на
# вакансию Стажер
# Отдела анализа СЗИ и формальной верификации и позже сообщит Вам о
# своем
# решении.
#
# С уважением,
# Максимова Александра»
#
#
# Вакансия: Стажер Отдела анализа СЗИ и
# формальной верификации
#
# компании: Группа компаний Астра
#
# Посмотреть вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/109143531?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested&utm_content=text&sent_date=2024_11_14&email_hash=8d943b26b592ba0cb731fb7b6bf5e054>
#
#
#
# *Те
# перь вы можете отписаться от этого типа письма. *
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested&se
# nt_date=2024_11_14&utm_content=feedback&email_hash=8d943b26b592ba0cb731fb7b6bf5e054>
# Управление
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested&sent_date=2024_11_14&utm_content=unsubscr
# ibe&email_hash=8d943b26b592ba0cb731fb7b6bf5e054>
# <https://vk.com/headhunter>
# <https://t.me/hh_ru_o
# fficial>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
#
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес
# 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний HeadHunter,
# 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 17:56
# Subject: Сообщение от работодателя
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested&sent_date=2024_11_14&utm_content=logo&email_hash=89a219c1c71e45c8a45360ecb439bb8e>
# «Здравствуйте, Руслан Ильдарович,
#
# Компания билайн: Бизнес рассмотрит Ваше резюме на вакансию
# Стажер-аналитик
# и позже сообщит Вам о своем решении.
#
# С уважением,
# Любавина Вера
# Олеговна»
#
#
# Вакансия: Стажер-аналитик
#
# компании: билайн: Бизнес
#
# Посмотреть вакансию можно
# по этой
# ссылке
# <https://hh.ru/vacancy/108053752?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested&utm_content=text&sent_date=2024_11_14&email_hash=89a219c1c71e45c8a45360ecb439bb8e>
#
#
#
# *Те
# перь вы можете отписаться от этого типа письма. *
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested&se
# nt_date=2024_11_14&utm_content=feedback&email_hash=89a219c1c71e45c8a45360ecb439bb8e>
# Управление
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested&sent_date=2024_11_14&utm_content=unsubscr
# ibe&email_hash=89a219c1c71e45c8a45360ecb439bb8e>
# <https://vk.com/headhunter>
# <https://t.me/hh_ru_o
# fficial>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
#
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес
# 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний HeadHunter,
# 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 18:45
# Subject: Работодатель не готов пригласить вас на собеседование
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested_mail&sent_date=2024_11_14&utm_content=logo&email_hash=87e136cf6a80409e9f6ee395ae29d
# 578>
# «Здравствуйте, Руслан!
# Большое спасибо за интерес, проявленный к вакансии. К сожалению,
# в
# настоящий момент мы не готовы пригласить Вас на дальнейшее интервью по этой
# вакансии. Мы
# внимательно ознакомились с Вашим резюме и, возможно, вернемся
# к Вашей кандидатуре, когда у нас
# возникнет такая потребность.
# С уважением,
# Каринэ Мкртчян»
#
#
#
# Вакансия: Разработчик в отдел
# нейросетей (ML-engineer)
#
# компании: TrueConf
#
# Посмотреть вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/109680179?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested_mail&utm_content=text&sent_date=2024_11_14&email_hash=87e136cf6a80409e9f6ee395ae29d578>
#
#
#
# Пожалуйста, не отвечайте на это письмо, так как оно отправлено с сервера.
# Для связи с
# работодателем используйте, пожалуйста, контакты, указанные в
# сообщении.
#
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested_ma
# il&sent_date=2024_11_14&utm_content=feedback&email_hash=87e136cf6a80409e9f6ee395ae29d578>
# Управлени
# е
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested_mail&sent_date=2024_11_14&utm_content=uns
# ubscribe&email_hash=87e136cf6a80409e9f6ee395ae29d578>
# <https://vk.com/headhunter>
# <https://t.me/hh
# _ru_official>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_
# 14>
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический
# адрес 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний
# HeadHunter, 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 18:36
# Subject: Работодатель не готов пригласить вас на собеседование
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested_mail&sent_date=2024_11_14&utm_content=logo&email_hash=1247924cfd708b0ae7a2f4efb9b4e
# d98>
# «Руслан, здравствуйте!
#
# Большое спасибо за интерес к вакансии! К сожалению, сейчас мы не
# готовы
# пригласить вас на следующий этап.
# Ценим ваше внимание и будем рады получать ваши отклики
# на другие позиции.
#
# Makarova Tatiana»
#
#
#
# Вакансия: Python/Django Junior
# Backend-разработчик
#
# компании: Placebo/25
#
# Посмотреть вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/110134917?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested_mail&utm_content=text&sent_date=2024_11_14&email_hash=1247924cfd708b0ae7a2f4efb9b4ed98>
#
#
#
# Пожалуйста, не отвечайте на это письмо, так как оно отправлено с сервера.
# Для связи с
# работодателем используйте, пожалуйста, контакты, указанные в
# сообщении.
#
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested_ma
# il&sent_date=2024_11_14&utm_content=feedback&email_hash=1247924cfd708b0ae7a2f4efb9b4ed98>
# Управлени
# е
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested_mail&sent_date=2024_11_14&utm_content=uns
# ubscribe&email_hash=1247924cfd708b0ae7a2f4efb9b4ed98>
# <https://vk.com/headhunter>
# <https://t.me/hh
# _ru_official>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_
# 14>
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический
# адрес 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний
# HeadHunter, 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: чт, 14 нояб. 2024 г. в
# 18:03
# Subject: Работодатель не готов пригласить вас на собеседование
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested_mail&sent_date=2024_11_14&utm_content=logo&email_hash=02f7b6d4fafaf698aadc1e877a177
# eb6>
# «Руслан Ильдарович, здравствуйте!
#
# Большое спасибо за интерес к вакансии! К сожалению,
# сейчас мы не готовы
# пригласить вас на следующий этап.
# Ценим ваше внимание и будем рады получать
# ваши отклики на другие позиции.
#
# Миллер Эдуард»
#
#
#
# Вакансия: Стажер Python Back-end
# (офис)
#
# компании: Caltat
#
# Посмотреть вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/109220041?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested_mail&utm_content=text&sent_date=2024_11_14&email_hash=02f7b6d4fafaf698aadc1e877a177eb6>
#
#
#
# Пожалуйста, не отвечайте на это письмо, так как оно отправлено с сервера.
# Для связи с
# работодателем используйте, пожалуйста, контакты, указанные в
# сообщении.
#
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested_ma
# il&sent_date=2024_11_14&utm_content=feedback&email_hash=02f7b6d4fafaf698aadc1e877a177eb6>
# Управлени
# е
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-14&t=hhappli
# cant_resume_status_update&s=43c6819d4dfa83bade4f295cb6c97cd40926bc6d3e128eed65867a99d34a4401&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested_mail&sent_date=2024_11_14&utm_content=uns
# ubscribe&email_hash=02f7b6d4fafaf698aadc1e877a177eb6>
# <https://vk.com/headhunter>
# <https://t.me/hh
# _ru_official>
# <https://hh.ru/mobile?from=dg_b_2024_11_14>
# <https://hh.ru/mobile?from=dg_b_2024_11_
# 14>
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический
# адрес 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний
# HeadHunter, 2000–2024
#
#
# ---------- Forwarded message ---------
# От: hh.ru <noreply@hh.ru>
# Date: пт, 15 нояб. 2024 г. в
# 08:16
# Subject: С вами хотят связаться по вакансии из «Титова Светлана
# Владимировна»
# To: Руслан
# <afarovruslancrypto@gmail.com>
#
#
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=co
# mpany_interested&sent_date=2024_11_15&utm_content=logo&email_hash=15d5f6e9cb4e011433b7dac33d231f3c>
# «Здравствуйте, Руслан Ильдарович!
#
# Нас заинтересовало Ваше резюме, поэтому мы хотим пригласить
# Вас на вакансию.
#
# Если наше предложение для Вас актуально:
# https://otklik.workpro.com.ru
#
# С
# уважением,
# Светлана Титова»
#
#
# Вакансия: Менеджер проверки данных
#
# компании: Титова Светлана
# Владимировна
#
# Посмотреть вакансию можно по этой
# ссылке
# <https://hh.ru/vacancy/109428871?utm_source=email&utm_medium=email&utm_campaign=company_inte
# rested&utm_content=text&sent_date=2024_11_15&email_hash=15d5f6e9cb4e011433b7dac33d231f3c>
#
#
#
# *Те
# перь вы можете отписаться от этого типа письма. *
# Вопросы и
# ответы
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested&se
# nt_date=2024_11_15&utm_content=feedback&email_hash=15d5f6e9cb4e011433b7dac33d231f3c>
# Управление
# рассылкой
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-15&t=hhappli
# cant_resume_status_update&s=f678993ea74f237df0e6bf614fa424e43d4b2a19df3d214d38720b06172404ed&utm_sou
# rce=email&utm_medium=email&utm_campaign=company_interested&sent_date=2024_11_15&utm_content=unsubscr
# ibe&email_hash=15d5f6e9cb4e011433b7dac33d231f3c>
# <https://vk.com/headhunter>
# <https://t.me/hh_ru_o
# fficial>
# <https://hh.ru/mobile?from=dg_b_2024_11_15>
# <https://hh.ru/mobile?from=dg_b_2024_11_15>
#
# Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес
# 129085, г. Москва, ул. Годовикова, д.9,
# стр.10, ОГРН 1067761906805
# © Группа компаний HeadHunter,
# 2000–2024
#
#
# <!doctype html>
# <html lang="ru" xmlns="http://www.w3.org/1999/xhtml"
# xmlns:v="urn:schemas-microsoft-com:vml" xmlns:o="urn:schemas-microsoft-com:office:office">
#
# <head>
#     <title>
#       Yandex ID
#     </title>
#     <!--[if !mso]><!-->
#     <meta
# http-equiv="X-UA-Compatible" content="IE=edge">
#     <!--<![endif]-->
#     <meta
# http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta name="viewport"
# content="width=device-width, initial-scale=1">
#     <style type="text/css">
#       #outlook a {
# padding:0; }
#       body {
# margin:0;padding:0;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%; }
#       table, td {
# border-collapse:collapse;mso-table-lspace:0pt;mso-table-rspace:0pt; }
#       img {
# border:0;height:auto;line-height:100%;
# outline:none;text-decoration:none;-ms-interpolation-mode:bicubic; }
#       p {
# display:block;margin:13px 0; }
#     </style>
#     <!--[if mso]>
#     <noscript>
#     <xml>
#
# <o:OfficeDocumentSettings>
#       <o:AllowPNG/>
#       <o:PixelsPerInch>96</o:PixelsPerInch>
#
# </o:OfficeDocumentSettings>
#     </xml>
#     </noscript>
#     <![endif]-->
#     <!--[if lte mso 11]>
#
# <style type="text/css">
#       .mj-outlook-group-fix { width:100% !important; }
#     </style>
#
# <![endif]-->
#
#       <!--[if !mso]><!-->
#         <link
# href="https://yastatic.net/s3/frontend/yandex-font/v0.2.0/browser.css" rel="stylesheet"
# type="text/css">
#         <style type="text/css">
#           @import
# url(https://yastatic.net/s3/frontend/yandex-font/v0.2.0/browser.css);
#         </style>
#
# <!--<![endif]-->
#
#
#
#     <style type="text/css">
#       @media only screen and (min-width:540px) {
#
# .mj-column-per-100 { width:100% !important; max-width: 100%; }
#       }
#     </style>
#     <style
# media="screen and (min-width:540px)">
#       .moz-text-html .mj-column-per-100 { width:100%
# !important; max-width: 100%; }
#     </style>
#
#
#     <style type="text/css">
#
#
#         .card a {
#
# color: #4D8EFF;
#         }
#         .card a:hover {
#             color: #FF4D4D;
#         }
#
# @media (prefers-color-scheme: dark ) {
#             .card a {
#               color: #6BA6F6
# !important;
#             }
#           }
#         [data-ogsc] .card a { color: #6BA6F6 !important; }
#
#
# @media only screen and (max-width:540px) {
#       table.mj-full-width-mobile { width: 100%
# !important; }
#       td.mj-full-width-mobile { width: auto !important; }
#     }
#
#           a {
#
# text-decoration: none;
#             font-weight: 500;
#           }
#           a:hover {
#
# color: #262633;
#           }
#           .text_size_s {
#             font-size: 16px;
#
# line-height: 22px;
#           }
#           .text_color_secondary {
#             color: #85889E;
#
# }
#           .text ul, .text ol {
#             margin: 0 0 0 28px;
#             padding: 0;
#
# }
#           .text li {
#             margin: 0 0 8px;
#             padding-left: 6px;
#           }
#
# p {
#             margin: 0 0 12px;
#           }
#
#     </style>
#     <style type="text/css">
#
#
# </style>
#
#   </head>
#   <body style="word-spacing:normal;background-color:#E5E5E5;">
#
#
#       <div
# style="background-color:#E5E5E5;">
#
#       <div
# style="height:24px;line-height:24px;">&#8202;</div>
#
#             <div style="margin: 0 8px">
#
#
#
# <!--[if mso | IE]><table align="center" border="0" cellpadding="0" cellspacing="0"
# class="card-outlook" role="presentation" style="width:520px;" width="520" bgcolor="#C5ECB8"
# ><tr><td style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><v:rect
# style="width:520px;" xmlns:v="urn:schemas-microsoft-com:vml" fill="true" stroke="false"><v:fill
# origin="0.5, 0" position="0.5, 0" src="https://id-mail.s3.yandex.net/security/security.png"
# color="#C5ECB8" type="tile" /><v:textbox style="mso-fit-shape-to-text:true"
# inset="0,0,0,0"><![endif]-->
#
#       <div class="card" style="background:#C5ECB8
# url('https://id-mail.s3.yandex.net/security/security.png') right top / auto
# no-repeat;background-position:right top;background-repeat:no-repeat;background-size:auto;margin:0px
# auto;border-radius:32px;max-width:520px;">
#         <div style="line-height:0;font-size:0;">
#
# <table align="center" background="https://id-mail.s3.yandex.net/security/security.png" border="0"
# cellpadding="0" cellspacing="0" role="presentation" style="background:#C5ECB8
# url('https://id-mail.s3.yandex.net/security/security.png') right top / auto
# no-repeat;background-position:right
# top;background-repeat:no-repeat;background-size:auto;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <table border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="border-collapse:collapse;border-spacing:0px;">
#
# <tbody>
#           <tr>
#             <td style="width:157px;">
#
#         <a
# href="https://passport.yandex.ru/profile" target="_blank" style="text-decoration: none;
# font-weight: 500;">
#
#       <img alt="Яндекс ID" height="auto"
# src="https://id-mail.s3.yandex.net/security/logo@2x.png"
# style="border:0;display:block;outline:none;text-decoration:none;height:auto;width:100%;font-size:13p
# x;" width="157">
#
#         </a>
#
#             </td>
#           </tr>
#         </tbody>
#       </table>
#
#
# </td>
#               </tr>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div
# style="height:50px;line-height:50px;">&#8202;</div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h1 style="font-size: 28px;
# line-height: 32px; margin: 0 0 16px 0; font-weight: 700">
#                     Вы создали пароль для
# приложения в аккаунте YourJobOffer2
#                 </h1></div>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td align="left" class="text"
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">21.11.2024 16:20<br>
#
# IP 93.175.4.228 • Долгопрудный</div>
#
#                 </td>
#               </tr>
#
#         </tbody>
#
# </table>
#
#       </div>
#
#           <!--[if mso | IE]></td></tr></table><![endif]-->
#
# </td>
#             </tr>
#           </tbody>
#         </table>
#         </div>
#       </div>
#
#
# <!--[if mso | IE]></v:textbox></v:rect></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#             <div
# style="margin: 0 8px">
#
#
#       <!--[if mso | IE]><table align="center" border="0" cellpadding="0"
# cellspacing="0" class="card-outlook" role="presentation" style="width:520px;" width="520"
# bgcolor="#ffffff" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# class="card" style="background:#ffffff;background-color:#ffffff;margin:0px
# auto;border-radius:32px;max-width:520px;">
#
#         <table align="center" border="0"
# cellpadding="0" cellspacing="0" role="presentation"
# style="background:#ffffff;background-color:#ffffff;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h2 style="font-size: 24px;
# line-height: 28px; margin: 0 0 16px 0; font-weight: 700">
#           Если это были не вы
#
# </h2></div>
#
#                 </td>
#               </tr>
#
#               <tr>
#                 <td
# align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;"><p style="margin: 0 0
# 12px;">
#           Первым делом, проверьте, что данные в аккаунте — точно ваши:
#       </p>
#
# <ul style="margin: 0 0 0 28px; padding: 0;">
#             <li style="margin: 0 0 8px; padding-left:
# 6px;"><a href="https://passport.yandex.ru/profile/phones?origin=passport_profile"
# style="text-decoration: none; font-weight: 500;">Номер телефона</a></li>
#             <li
# style="margin: 0 0 8px; padding-left: 6px;"><a
# href="https://passport.yandex.ru/profile/change-hint" style="text-decoration: none; font-weight:
# 500;">Контрольный вопрос</a></li>
#             <li style="margin: 0 0 8px; padding-left: 6px;"><a
# href="https://passport.yandex.ru/profile" style="text-decoration: none; font-weight:
# 500;">Дополнительные почты</a></li>
#           </ul>
#           <p style="margin: 0 0 12px;">
#
# После этого обязательно <a href="https://passport.yandex.ru/profile/password"
# style="text-decoration: none; font-weight: 500;">смените пароль</a> — так вы не оставите лазеек
# злоумышленникам.
#
#           </p></div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="center" vertical-align="middle" style="font-size:0px;padding:32px
# 0;padding-top:20px;word-break:break-word;">
#
#       <table border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="border-collapse:separate;line-height:100%;">
#
# <tbody>
#           <tr>
#             <td align="center" bgcolor="#FDDE55" role="presentation"
# style="border:none;border-radius:16px;cursor:auto;mso-padding-alt:18px 66px;background:#FDDE55;"
# valign="middle">
#               <a href="https://passport.yandex.ru/profile/password"
# style="display: inline-block; background: #FDDE55; color: #361600; font-family: YS Text, Arial,
# sans-serif; font-size: 16px; font-weight: normal; line-height: 120%; margin: 0; text-decoration:
# none; text-transform: none; padding: 18px 66px; mso-padding-alt: 0px; border-radius: 16px;"
# target="_blank">
#                   Сменить пароль
#               </a>
#             </td>
#
# </tr>
#         </tbody>
#       </table>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#
# <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">
#
#
# Если не получается войти в аккаунт, попробуйте <a
# href="https://passport.yandex.ru/passport?mode=restore&uid=2051232599" style="text-decoration:
# none; font-weight: 500;">восстановить доступ</a> или <a
# href="https://yandex.ru/support/id/feedback.html" style="text-decoration: none; font-weight:
# 500;">напишите в службу поддержки</a>.
#
#       </div>
#
#                 </td>
#
# </tr>
#
#         </tbody>
#       </table>
#
#       </div>
#
#           <!--[if mso |
# IE]></td></tr></table><![endif]-->
#               </td>
#             </tr>
#           </tbody>
#
# </table>
#
#       </div>
#
#
#       <!--[if mso | IE]></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#             <div
# style="margin: 0 8px">
#
#
#       <!--[if mso | IE]><table align="center" border="0" cellpadding="0"
# cellspacing="0" class="card-outlook" role="presentation" style="width:520px;" width="520"
# bgcolor="#ffffff" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# class="card" style="background:#ffffff;background-color:#ffffff;margin:0px
# auto;border-radius:32px;max-width:520px;">
#
#         <table align="center" border="0"
# cellpadding="0" cellspacing="0" role="presentation"
# style="background:#ffffff;background-color:#ffffff;width:100%;border-radius:32px;">
#
# <tbody>
#             <tr>
#               <td
# style="direction:ltr;font-size:0px;padding:32px;text-align:center;">
#                 <!--[if mso |
# IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:456px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# style="font-size:0px;word-break:break-word;">
#
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:13px;line-height:1;text-align:left;color:#262633;"><h2 style="font-size: 24px;
# line-height: 28px; margin: 0 0 16px 0; font-weight: 700">
#                     Как защитить аккаунт
# от злоумышленников
#                 </h2></div>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td align="left" class="text" style="font-size:0px;word-break:break-word;">
#
#
# <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">
#           <p
# style="margin: 0 0 12px;">
#
#               Загляните на наш обучающий лендинг: <a
# href="https://id.yandex.ru/howtoprotectyourid" style="text-decoration: none; font-weight:
# 500;">«Как сделать защиту аккаунта на Яндексе ещё сильнее»</a>.
#
#           </p>
#
# <p style="margin: 0 0 12px;">Вот несколько советов:</p></div>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#
# <table style="margin-bottom: 24px;">
#                 <tr>
#                     <td style="width:
# 44px; vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/phone.png);
#                         background-position:
# 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Привяжите номер
# телефона
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px;
# font-size: 16px; line-height: 22px; color: #85889E;">Это поможет быстро восстанавливать
# доступ</p></div>
#     </td>
#                 </tr>
#             </table>
#
#                 </td>
#
# </tr>
#
#               <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#
# <table style="margin-bottom: 24px;">
#                 <tr>
#                     <td style="width:
# 44px; vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/key.png);
#                         background-position:
# 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Придумайте сложный
# пароль
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px;
# font-size: 16px; line-height: 22px; color: #85889E;">Обязательно с буквами и цифрами</p></div>
#
# </td>
#                 </tr>
#             </table>
#
#                 </td>
#               </tr>
#
#
# <tr>
#                 <td style="font-size:0px;word-break:break-word;">
#
#             <table
# style="margin-bottom: 0px;">
#                 <tr>
#                     <td style="width: 44px;
# vertical-align:top; ">
#                     <div style="
#                         width: 44px;
#
# height: 44px;
#                         border-radius: 16px;
#
# background-color: #EDFFF4;
#                         background-image:
# url(https://id-mail.s3.yandex.net/security/shield.png);
#
# background-position: 50% 50%;
#                         background-size: 24px 24px;
#
# background-repeat: no-repeat;
#                     "></div>
#                     </td>
#
# <td style="padding-left: 24px;">
#       <div style="font-family:YS Text, Arial,
# sans-serif;font-size:18px;line-height:24px;text-align:left;color:#262633;">Включите подтверждение
# входа
#               <p class="text_size_s text_color_secondary" style="margin: 0 0 12px; font-size:
# 16px; line-height: 22px; color: #85889E;">Входите с паролем и смс или с приложением Яндекс
# Ключ</p></div>
#     </td>
#                 </tr>
#             </table>
#
#                 </td>
#
# </tr>
#
#         </tbody>
#       </table>
#
#       </div>
#
#           <!--[if mso |
# IE]></td></tr></table><![endif]-->
#               </td>
#             </tr>
#           </tbody>
#
# </table>
#
#       </div>
#
#
#       <!--[if mso | IE]></td></tr></table><![endif]-->
#
#
#       <div
# style="height:12px;line-height:12px;">&#8202;</div>
#
#             </div>
#
#
#       <!--[if mso |
# IE]><table align="center" border="0" cellpadding="0" cellspacing="0" class="" role="presentation"
# style="width:520px;" width="520" ><tr><td
# style="line-height:0px;font-size:0px;mso-line-height-rule:exactly;"><![endif]-->
#
#
#       <div
# style="margin:0px auto;max-width:520px;">
#
#         <table align="center" border="0" cellpadding="0"
# cellspacing="0" role="presentation" style="width:100%;">
#           <tbody>
#             <tr>
#
# <td style="direction:ltr;font-size:0px;padding:20px 0;text-align:center;">
#                 <!--[if
# mso | IE]><table role="presentation" border="0" cellpadding="0" cellspacing="0"><tr><td class=""
# style="vertical-align:top;width:520px;" ><![endif]-->
#
#       <div class="mj-column-per-100
# mj-outlook-group-fix"
# style="font-size:0px;text-align:left;direction:ltr;display:inline-block;vertical-align:top;width:100
# %;">
#
#       <table border="0" cellpadding="0" cellspacing="0" role="presentation"
# style="vertical-align:top;" width="100%">
#         <tbody>
#
#               <tr>
#                 <td
# align="center" class="text" style="font-size:0px;word-break:break-word;">
#
#       <div
# style="font-family:YS Text, Arial,
# sans-serif;font-size:16px;line-height:22px;text-align:center;color:#85889E;">На это письмо не нужно
# отвечать.<br>
#       <a href="https://id.yandex.ru/helpdesk/e0271d00-30f7-9cf7-4c16-c3f95d5b10cd"
# style="text-decoration: none; font-weight: 500; color: #85889E;">Связаться с поддержкой Яндекс
# ID</a></div>
#
#                 </td>
#               </tr>
#
#         </tbody>
#       </table>
#
#
# </div>
#
#           <!--[if mso | IE]></td></tr></table><![endif]-->
#               </td>
#
# </tr>
#           </tbody>
#         </table>
#
#       </div>
#
#
#       <!--[if mso |
# IE]></td></tr></table><![endif]-->
#
#
#       </div>
#
#   </body>
# </html>
#
# пт, 15 нояб. 2024 г. в 09:40, hh.ru <noreply@hh.ru>:
#
# >
# >
# <https://hh.ru?utm_source=email&utm_medium=email&utm_campaign=company_interested&sent_date=2024_11_1
# 5&utm_content=logo&email_hash=b88330e61ec4f5fe2898f2a8faf3a471>
# > «Dear Руслан Ильдарович,
# >
# >
# This is to confirm that we have received your application. Thank you for
# > your interest in the
# opportunities available at P&G, and we would like to
# > invite you to submit your application
# online following this link:
# >
# >
# https://pg.wd5.myworkdayjobs.com/1000/job/Moscow/Data-Engineer-Intern_R000116356?source=RS_HEADHUNTE
# RRU
# >
# >
# > What you need to do:
# >
# > 1. Click on the “apply” button.
# > 2. Complete the online
# application form and attach your CV so that it gets
# > uploaded into our database.
# > 3. When your
# CV has been screened successfully, you will receive the link
# > to the online assessment within one
# week from the point of registration.
# > 4. If you pass the online assessment, you will be invited
# to a series of
# > interviews with our experienced managers.
# >
# > You can find more information on
# www.pgcareers.com, including how to
# > prepare for our hiring process. If you have already been
# considered for a
# > position at P&G in the last 12 months, please expect an email from our P&G
# >
# Recruiting team to explain your current application status. You can also
# > contact us directly at
# pgeuropecareers.im@pg.com.
# >
# > Best regards,
# > P&G Careers»
# >
# >
# > Вакансия: Data Engineering
# Intern / Стажер дата-инженер
# >
# > компании: «Procter & Gamble», Студент
# >
# > Посмотреть вакансию
# можно по этой ссылке
# >
# <https://hh.ru/vacancy/107950092?utm_source=email&utm_medium=email&utm_campaign=company_interested&u
# tm_content=text&sent_date=2024_11_15&email_hash=b88330e61ec4f5fe2898f2a8faf3a471>
# >
# >
# >
# >
# *Теперь вы можете отписаться от этого типа письма. *
# > Вопросы и ответы
# >
# <https://hh.ru/feedback?utm_source=email&utm_medium=email&utm_campaign=company_interested&sent_date=
# 2024_11_15&utm_content=feedback&email_hash=b88330e61ec4f5fe2898f2a8faf3a471>
# > Управление
# рассылкой
# >
# <https://hh.ru/unsubscribe/7cd11ffd-ab46-453c-ada2-a68011df51f1?date=2024-11-15&t=hhapplicant_resume
# _status_update&s=f678993ea74f237df0e6bf614fa424e43d4b2a19df3d214d38720b06172404ed&utm_source=email&u
# tm_medium=email&utm_campaign=company_interested&sent_date=2024_11_15&utm_content=unsubscribe&email_h
# ash=b88330e61ec4f5fe2898f2a8faf3a471>
# > <https://vk.com/headhunter>
# >
# <https://t.me/hh_ru_official>
# > <https://hh.ru/mobile?from=dg_b_2024_11_15>
# >
# <https://hh.ru/mobile?from=dg_b_2024_11_15>
# > Вы получили это письмо, поскольку зарегистрированы
# на hh.ru
# > ООО "Хэдхантер", юридический адрес 129085, г. Москва, ул. Годовикова, д.9,
# > стр.10,
# ОГРН 1067761906805
# > © Группа компаний HeadHunter, 2000–2024
# >

# %%
from your_job_offer.use_cases.tracking.email_parser import parser

def to_str(msg):
    if msg is None:
        return None
    return f"{msg.vacancy_key.job}, {msg.vacancy_key.employer}, {msg.stage.stage_type}"

ans = parser.parse(cleaned)
for clean, parsed in zip(cleaned, ans):
    print("Сообщение")
    print_with_line_breaks(clean.body)
    print(f"Результат: {to_str(parsed)}")
    print("------------------------\n")
# Out:
# Сообщение
#  Yandex ID Вы создали пароль для приложения в аккаунте YourJobOffer2 21.11.2024 12:39 IP
# 89.113.147.183 • Москва Если это были не вы Первым делом, проверьте, что данные в аккаунте — точно
# ваши: Номер телефона Контрольный вопрос Дополнительные почты После этого обязательно смените пароль
# — так вы не оставите лазеек злоумышленникам. Сменить пароль Если не получается войти в аккаунт,
# попробуйте восстановить доступ или напишите в службу поддержки. Как защитить аккаунт от
# злоумышленников Загляните на наш обучающий лендинг: «Как сделать защиту аккаунта на Яндексе ещё
# сильнее». Вот несколько советов: Привяжите номер телефона Это поможет быстро восстанавливать доступ
# Придумайте сложный пароль Обязательно с буквами и цифрами Включите подтверждение входа Входите с
# паролем и смс или с приложением Яндекс Ключ На это письмо не нужно отвечать. Связаться с поддержкой
# Яндекс ID
#
# Результат: None
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 18:20 Subject:
# Сообщение от работодателя To: Руслан «Здравствуйте, Руслан Ильдарович, Компания Группа компаний
# Астра рассмотрит Ваше резюме на вакансию Стажер мантейнер и позже сообщит Вам о своем решении. С
# уважением, Максимова Александра» Вакансия: Стажер мантейнер компании: Группа компаний Астра
# Посмотреть вакансию можно по этой ссылке *Теперь вы можете отписаться от этого типа письма. *
# Вопросы и ответы Управление рассылкой Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН
# 1067761906805 © Группа компаний HeadHunter, 2000–2024
#
# Результат: Стажер мантейнер, Группа компаний Астра, StageEnum.CONSIDERATION
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 18:20 Subject:
# Сообщение от работодателя To: Руслан «Здравствуйте, Руслан Ильдарович, Компания Группа компаний
# Астра рассмотрит Ваше резюме на вакансию Стажер Отдела анализа СЗИ и формальной верификации и позже
# сообщит Вам о своем решении. С уважением, Максимова Александра» Вакансия: Стажер Отдела анализа СЗИ
# и формальной верификации компании: Группа компаний Астра Посмотреть вакансию можно по этой ссылке
# *Теперь вы можете отписаться от этого типа письма. * Вопросы и ответы Управление рассылкой Вы
# получили это письмо, поскольку зарегистрированы на hh.ru ООО "Хэдхантер", юридический адрес 129085,
# г. Москва, ул. Годовикова, д.9, стр.10, ОГРН 1067761906805 © Группа компаний HeadHunter, 2000–2024
#
# Результат: Стажер Отдела анализа СЗИ и формальной верификации, Группа компаний Астра, StageEnum.CONSIDERATION
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 17:56 Subject:
# Сообщение от работодателя To: Руслан «Здравствуйте, Руслан Ильдарович, Компания билайн: Бизнес
# рассмотрит Ваше резюме на вакансию Стажер-аналитик и позже сообщит Вам о своем решении. С
# уважением, Любавина Вера Олеговна» Вакансия: Стажер-аналитик компании: билайн: Бизнес Посмотреть
# вакансию можно по этой ссылке *Теперь вы можете отписаться от этого типа письма. * Вопросы и ответы
# Управление рассылкой Вы получили это письмо, поскольку зарегистрированы на hh.ru ООО "Хэдхантер",
# юридический адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН 1067761906805 © Группа
# компаний HeadHunter, 2000–2024
#
# Результат: Стажер-аналитик, билайн: Бизнес, StageEnum.CONSIDERATION
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 18:45 Subject:
# Работодатель не готов пригласить вас на собеседование To: Руслан «Здравствуйте, Руслан! Большое
# спасибо за интерес, проявленный к вакансии. К сожалению, в настоящий момент мы не готовы пригласить
# Вас на дальнейшее интервью по этой вакансии. Мы внимательно ознакомились с Вашим резюме и,
# возможно, вернемся к Вашей кандидатуре, когда у нас возникнет такая потребность. С уважением,
# Каринэ Мкртчян» Вакансия: Разработчик в отдел нейросетей (ML-engineer) компании: TrueConf
# Посмотреть вакансию можно по этой ссылке Пожалуйста, не отвечайте на это письмо, так как оно
# отправлено с сервера. Для связи с работодателем используйте, пожалуйста, контакты, указанные в
# сообщении. Вопросы и ответы Управление рассылкой Вы получили это письмо, поскольку зарегистрированы
# на hh.ru ООО "Хэдхантер", юридический адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН
# 1067761906805 © Группа компаний HeadHunter, 2000–2024
#
# Результат: Разработчик в отдел нейросетей (ML-engineer), TrueConf, StageEnum.REJECT
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 18:36 Subject:
# Работодатель не готов пригласить вас на собеседование To: Руслан «Руслан, здравствуйте! Большое
# спасибо за интерес к вакансии! К сожалению, сейчас мы не готовы пригласить вас на следующий этап.
# Ценим ваше внимание и будем рады получать ваши отклики на другие позиции. Makarova Tatiana»
# Вакансия: Python/Django Junior Backend-разработчик компании: Placebo/25 Посмотреть вакансию можно
# по этой ссылке Пожалуйста, не отвечайте на это письмо, так как оно отправлено с сервера. Для связи
# с работодателем используйте, пожалуйста, контакты, указанные в сообщении. Вопросы и ответы
# Управление рассылкой Вы получили это письмо, поскольку зарегистрированы на hh.ru ООО "Хэдхантер",
# юридический адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН 1067761906805 © Группа
# компаний HeadHunter, 2000–2024
#
# Результат: Python/Django Junior Backend-разработчик, Placebo/25, StageEnum.REJECT
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: чт, 14 нояб. 2024 г. в 18:03 Subject:
# Работодатель не готов пригласить вас на собеседование To: Руслан «Руслан Ильдарович, здравствуйте!
# Большое спасибо за интерес к вакансии! К сожалению, сейчас мы не готовы пригласить вас на следующий
# этап. Ценим ваше внимание и будем рады получать ваши отклики на другие позиции. Миллер Эдуард»
# Вакансия: Стажер Python Back-end (офис) компании: Caltat Посмотреть вакансию можно по этой ссылке
# Пожалуйста, не отвечайте на это письмо, так как оно отправлено с сервера. Для связи с работодателем
# используйте, пожалуйста, контакты, указанные в сообщении. Вопросы и ответы Управление рассылкой Вы
# получили это письмо, поскольку зарегистрированы на hh.ru ООО "Хэдхантер", юридический адрес 129085,
# г. Москва, ул. Годовикова, д.9, стр.10, ОГРН 1067761906805 © Группа компаний HeadHunter, 2000–2024
#
# Результат: Стажер Python Back-end (офис), Caltat, StageEnum.REJECT
# ------------------------
#
# Сообщение
# ---------- Forwarded message --------- От: hh.ru Date: пт, 15 нояб. 2024 г. в 08:16 Subject: С вами
# хотят связаться по вакансии из «Титова Светлана Владимировна» To: Руслан «Здравствуйте, Руслан
# Ильдарович! Нас заинтересовало Ваше резюме, поэтому мы хотим пригласить Вас на вакансию. Если наше
# предложение для Вас актуально: https://otklik.workpro.com.ru С уважением, Светлана Титова»
# Вакансия: Менеджер проверки данных компании: Титова Светлана Владимировна Посмотреть вакансию можно
# по этой ссылке *Теперь вы можете отписаться от этого типа письма. * Вопросы и ответы Управление
# рассылкой Вы получили это письмо, поскольку зарегистрированы на hh.ru ООО "Хэдхантер", юридический
# адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН 1067761906805 © Группа компаний
# HeadHunter, 2000–2024
#
# Результат: Менеджер проверки данных, Титова Светлана Владимировна, StageEnum.INVITE
# ------------------------
#
# Сообщение
#  Yandex ID Вы создали пароль для приложения в аккаунте YourJobOffer2 21.11.2024 16:20 IP
# 93.175.4.228 • Долгопрудный Если это были не вы Первым делом, проверьте, что данные в аккаунте —
# точно ваши: Номер телефона Контрольный вопрос Дополнительные почты После этого обязательно смените
# пароль — так вы не оставите лазеек злоумышленникам. Сменить пароль Если не получается войти в
# аккаунт, попробуйте восстановить доступ или напишите в службу поддержки. Как защитить аккаунт от
# злоумышленников Загляните на наш обучающий лендинг: «Как сделать защиту аккаунта на Яндексе ещё
# сильнее». Вот несколько советов: Привяжите номер телефона Это поможет быстро восстанавливать доступ
# Придумайте сложный пароль Обязательно с буквами и цифрами Включите подтверждение входа Входите с
# паролем и смс или с приложением Яндекс Ключ На это письмо не нужно отвечать. Связаться с поддержкой
# Яндекс ID
#
# Результат: None
# ------------------------
#
# Сообщение
# пт, 15 нояб. 2024 г. в 09:40, hh.ru : «Dear Руслан Ильдарович, This is to confirm that we have
# received your application. Thank you for your interest in the opportunities available at P&G, and
# we would like to invite you to submit your application online following this link:
# https://pg.wd5.myworkdayjobs.com/1000/job/Moscow/Data-Engineer-Intern_R000116356?source=RS_HEADHUNTE
# RRU What you need to do: 1. Click on the “apply” button. 2. Complete the online application form
# and attach your CV so that it gets uploaded into our database. 3. When your CV has been screened
# successfully, you will receive the link to the online assessment within one week from the point of
# registration. 4. If you pass the online assessment, you will be invited to a series of interviews
# with our experienced managers. You can find more information on www.pgcareers.com, including how to
# prepare for our hiring process. If you have already been considered for a position at P&G in the
# last 12 months, please expect an email from our P&G Recruiting team to explain your current
# application status. You can also contact us directly at pgeuropecareers.im@pg.com. Best regards,
# P&G Careers» Вакансия: Data Engineering Intern / Стажер дата-инженер компании: «Procter & Gamble»,
# Студент Посмотреть вакансию можно по этой ссылке *Теперь вы можете отписаться от этого типа письма.
# * Вопросы и ответы Управление рассылкой Вы получили это письмо, поскольку зарегистрированы на hh.ru
# ООО "Хэдхантер", юридический адрес 129085, г. Москва, ул. Годовикова, д.9, стр.10, ОГРН
# 1067761906805 © Группа компаний HeadHunter, 2000–2024
#
# Результат: Data Engineering Intern / Стажер дата-инженер, Procter & Gamble, StageEnum.INVITE
# ------------------------
