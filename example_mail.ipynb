# %%
from your_job_offer.domain.tracking.methods import get_all_stages
from your_job_offer.utils.mock import get_user

stages = get_all_stages(get_user())
for stage in stages:
    print(stage.vacancy.job)
    for stg in stage.stages:
        print(stg.stage_type)
        print(stg.message)
# Out:
# 109143498
# StageEnum.CONSIDERATION
# «Здравствуйте, Руслан Ильдарович, Компания Группа компаний Астра рассмотрит Ваше резюме на вакансию Стажер мантейнер и позже сообщит Вам о своем решении. С уважением, Максимова Александра»
# 109143531
# StageEnum.CONSIDERATION
# «Здравствуйте, Руслан Ильдарович, Компания Группа компаний Астра рассмотрит Ваше резюме на вакансию Стажер Отдела анализа СЗИ и формальной верификации и позже сообщит Вам о своем решении. С уважением, Максимова Александра»
# 108053752
# StageEnum.CONSIDERATION
# «Здравствуйте, Руслан Ильдарович, Компания билайн: Бизнес рассмотрит Ваше резюме на вакансию Стажер-аналитик и позже сообщит Вам о своем решении. С уважением, Любавина Вера Олеговна»
# 109680179
# StageEnum.REJECT
# ...

# %% [markdown]
# Заметки к встрече
#
# - Как хранить пароли?
# - Нужно уметь давать пользователю заходить на hh.ru для общения с нанимателем
# - Что насчёт уведомлений? Должен быть такой механизм
# - У нас будет 4 папки: ожидание, отказ, приглашение, uninteresting
# - Что должно отображаться во фронте по отслеживанию? Компания, вакансия, сообщение, кнопка посмотреть подробнее вакансию
# Это значит надо уметь по id вакансии находить саму вакансию и её выыводить
# - Как мы поймем, что человек успешно прособеседовался? Можно просить отмечать, чем все кончилось
